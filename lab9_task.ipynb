# %% [markdown]
# ## 1. Data Loading / Reading

# %%
# Import required libraries
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_csv('car_sales_data.csv')
print("Dataset loaded successfully!")
print(f"Total records: {len(df)}")

# %% [markdown]
# ## 2. Data Exploration

# %%
# Display first 5 rows
print("First 5 rows of the dataset:")
df.head()

# %%
# Display last 5 rows
print("Last 5 rows of the dataset:")
df.tail()

# %%
# Dataset shape
print(f"Dataset Shape: {df.shape}")
print(f"Number of Rows: {df.shape[0]}")
print(f"Number of Columns: {df.shape[1]}")

# %%
# Column names and data types
print("Column Information:")
df.info()

# %%
# Statistical summary of numerical columns
print("Statistical Summary:")
df.describe()

# %%
# Check for missing values
print("Missing Values:")
print(df.isnull().sum())
print(f"\nTotal Missing Values: {df.isnull().sum().sum()}")

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"Number of Duplicate Rows: {duplicates}")

# %%
# Display unique values for categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns
print("Unique values in categorical columns:")
for col in categorical_cols:
    print(f"\n{col}: {df[col].nunique()} unique values")
    print(df[col].value_counts().head())

# %%
# Display random sample of 10 rows
print("Random sample of 10 rows:")
df.sample(10)

# %% [markdown]
# ## Summary
# - Dataset successfully loaded from CSV file
# - Explored data structure, shape, and types
# - Analyzed missing values and duplicates
# - Examined statistical properties of numerical and categorical columns
